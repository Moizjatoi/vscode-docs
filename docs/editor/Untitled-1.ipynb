# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>University Information Portal</title>
    <style>
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            margin: 20px;
            background-color: #f8f9fa;
            color: #333;
        }

        input[type="text"], input[type="password"] {
            padding: 10px;
            margin-bottom: 15px;
            width: 100%;
            box-sizing: border-box;
            border: 1px solid #ced4da;
            border-radius: 4px;
        }

        button {
            padding: 15px;
            background-color: #007bff;
            color: white;
            border: none;
            border-radius: 4px;
            cursor: pointer;
            width: 100%;
            box-sizing: border-box;
            font-size: 16px;
        }

        button:hover {
            background-color: #0056b3;
        }

        table {
            width: 100%;
            border-collapse: collapse;
            margin-top: 30px;
        }

        table, th, td {
            border: 1px solid #ced4da;
        }

        th, td {
            padding: 15px;
            text-align: left;
            white-space: nowrap; /* Prevent text wrapping */
        }

        th {
            background-color: #007bff;
            color: white;
        }

        .search-bar {
            margin-top: 30px;
            display: none;
        }

        .search-input {
            padding: 10px;
            border: 1px solid #ced4da;
            border-radius: 4px;
            width: 100%;
            box-sizing: border-box;
        }

        #data-container {
            max-width: 1000px;
            margin: 30px auto;
            background-color: white;
            padding: 20px;
            border-radius: 8px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
        }

        /* Alternating row colors */
        #data-body tr:nth-child(even) {
            background-color: #f2f2f2;
        }
    </style>
</head>
<body>

    <div id="login-container" style="max-width: 400px; margin: auto; background-color: white; padding: 20px; border-radius: 8px; box-shadow: 0 0 10px rgba(0,0,0,0.1);">
        <h2 style="text-align: center; color: #333;">Login</h2>
        <label for="username">Username:</label>
        <input type="text" id="username" placeholder="Enter your username">
        <label for="password">Password:</label>
        <input type="password" id="password" placeholder="Enter your password">
        <button onclick="login()">Login</button>
    </div>

    <div id="data-container" class="search-bar">
        <label for="search">Search:</label>
        <input type="text" id="search" onkeyup="searchData()" placeholder="Search for data" class="search-input">

        <table>
            <thead>
                <tr>
                    <th style="width: 10%;">Country</th>
                    <th style="width: 20%;">Universities</th>
                    <th style="width: 15%;">Department</th>
                    <th style="width: 10%;">Duration</th>
                    <th style="width: 15%;">Admission Fees</th>
                    <th style="width: 15%;">Tuition Fees</th>
                    <th style="width: 15%;">Initial Deposit</th>
                </tr>
            </thead>
            <tbody id="data-body">
                <!-- Data will be displayed here dynamically -->
            </tbody>
        </table>
    </div>

    <script>
        var isLoggedIn = false; // Variable to track login status

        function login() {
            if (isLoggedIn) {
                return; // Prevent login function from being triggered twice
            }

            var username = document.getElementById('username').value;
            var password = document.getElementById('password').value;

            // Add your authentication logic here
            // For simplicity, let's assume the username and password are correct.
            if (username === 'Galaxy110' && password === 'your_password') {
                document.getElementById('login-container').style.display = 'none';
                document.getElementById('data-container').style.display = 'block';
                populateTable();
                isLoggedIn = true; // Set login status to true
            } else {
                alert('Invalid username or password');
            }
        }

        function populateTable() {
            // Data to be displayed
            var data = [
                ["Georgia", "SEU GEORGIAN NATIONAL", "MBBS/MD", "5+1 YEARS", "$ 5500 USD", "$ 2750 USD", "$ 500 USD"],
                ["Georgia", "UNIK-KUTAISI", "MBBS/MD", "5+1 YEARS", "$ 4750 USD", "$ 2000 USD", "$ 500 USD"],
                ["Georgia", "TBILISI MEDICAL ACADEMY", "MBBS/MD", "5+1 YEARS", "$ 6500 USD", "$ 3500 USD", "$ 500 USD"],
                ["Georgia", "ALTE UNIVERSITY", "MBBS/MD & BDS", "5+1 YEARS (For BDS 4+1 YEAR)", "$ 5500 USD (For BDS $5000 USD)", "$ 2750 USD (For BDS $2250 USD)", "$ 500 USD"],
                ["Georgia", "TBILISI STATE MEDICAL", "MBBS/MD", "5+1 YEARS", "$ 11000 USD", "3rd year $4000 USD", "$ 500 USD"],
                ["Georgia", "ALTE UNIVERSITY", "Computer Science", "4 YEARS", "$ 4500 USD", "$ 1500 USD", "$ 500 USD"],
                ["Georgia", "EAST-WEST", "MBBS/MD", "5+1 YEARS", "$ 4750 USD", "$ 2000 USD", "$ 500 USD"],
                ["Russia", "YAROSLAVL STATE MEDICAL UNIVERSITY", "MBBS/ MD/BDS", "5+1 YEAR", "$ 4250 USD", "$ 1500 USD", "N/A"],
                ["Russia", "YAROSLAVL THE WISE NOVGOROD STATE MEDICAL UNIVERSITY", "MBBS/ MD/BDS", "5+1 YEAR", "$ 4700 USD", "$ 1750 USD", "N/A"],
                ["China", "HUBEI UNIVERSITY OF ARTS & SCIENCE", "MBBS", "5+1 YEAR", "28,000 RMB", "21,000 RMB", "1,000 RMB"],
                ["China", "SHANDONG FIRST MEDICAL UNIVERSITY", "MBBS", "5+1 YEAR", "30,000 RMB", "26,400 RMB", "1,000 RMB"]
                // Add more data as needed
            ];

            var tbody = document.getElementById('data-body');
            tbody.innerHTML = '';

            for (var i = 0; i < data.length; i++) {
                var row = tbody.insertRow(i);

                for (var j = 0; j < data[i].length; j++) {
                    var cell = row.insertCell(j);
                    cell.innerHTML = data[i][j];
                }
            }
        }

        function searchData() {
            var input, filter, table, tr, td, i, txtValue;
            input = document.getElementById("search");
            filter = input.value.toUpperCase();
            table = document.getElementById("data-body");
            tr = table.getElementsByTagName("tr");

            for (i = 0; i < tr.length; i++) {
                td = tr[i].getElementsByTagName("td");
                var found = false;

                for (var j = 0; j < td.length; j++) {
                    if (td[j]) {
                        txtValue = td[j].textContent || td[j].innerText;
                        if (txtValue.toUpperCase().indexOf(filter) > -1) {
                            found = true;
                            break;
                        }
                    }
                }

                if (found) {
                    tr[i].style.display = "";
                } else {
                    tr[i].style.display = "none";
                }
            }
        }
    </script>

</body>
</html>
